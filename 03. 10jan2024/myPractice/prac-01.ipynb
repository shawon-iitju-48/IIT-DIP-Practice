# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2

# %%
print(cv2.__version__)
# Out:
# 4.9.0

# %%
img=cv2.imread("flower.jpg",cv2.IMREAD_COLOR)
img=cv2.resize(img,(600,600))
cv2.imshow("my flower",img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
rgbimage=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(rgbimage)
plt.title("My Flower")
# Out:
# Text(0.5, 1.0, 'My Flower')

# %%
img.shape
# Out:
# (600, 600, 3)

# %%
path=r"C:\Users\shawo\Documents\PythonPrep\IIT-DIP-Practice\10jan2024\myPractice\flower.jpg"
img2=cv2.imread(path,cv2.IMREAD_COLOR)
img2=cv2.resize(img2,(600,600))
cv2.imshow("fefa",img2)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
directory=r"C:\Users\shawo\Documents\PythonPrep\IIT-DIP-Practice\10jan2024\myPractice\Test Folder"

# %%
import os
os.chdir(directory)

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints']

# %%
filename="flower1.jpg"
cv2.imwrite(filename,img2)
# Out:
# True

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints', 'flower1.jpg']
